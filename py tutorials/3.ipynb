# %%
f = "vaibhav"
l = "avhad"

# %%
l + " " + f
# Out:
# 'avhad vaibhav'

# %%
name = f" My name is {f} {l}."
print(name)
# Out:
#  My name is vaibhav avhad.

# %%
a = "MY age is : "
age = 35
a+str(age)
# Out:
# 'MY age is : 35'

# %%
recipe = '''
Search services have new settings to manage history and personalised recommendations that reflect your prior Web & App Activity preferences. Media (like your images and audio) from your interactions will now also be saved in your history. You can make changes to your settings any time.
'''
recipe
# Out:
# '\nSearch services have new settings to manage history and personalised recommendations that reflect your prior Web & App Activity preferences. Media (like your images and audio) from your interactions will now also be saved in your history. You can make changes to your settings any time.\n'

# %%
recipe.find("settings", 3)
# Out:
# 26

# %%
a = "The Himalayas are one of the youngest mountain range on the planet."
a
# Out:
# 'The Himalayas are one of the youngest mountain range on the planet.'

# %%
a[:13]
# Out:
# 'The Himalayas'

# %%
a[-29:-15]
# Out:
# 'mountain range'

# %%
b = f"{a[:13]} {a[-14:-1]}"
b
# Out:
# 'The Himalayas on the planet'

# %%
st = "Abhad"
st.upper()
# Out:
# 'ABHAD'

# %%
st.upper("akld")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 st.upper("akld")
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
st.find("h")
# Out:
# 2
