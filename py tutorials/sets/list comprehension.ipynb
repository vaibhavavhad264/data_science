# %%
import time
from os import times_result

# %%
num = range(10000000)
sq_num = []

st_time = time.time()
for num in num :
    sq_num.append(num ** 2)
end_time = time.time()
end_time - st_time
# Out:
# 2.1182749271392822

# %%
st_time = time.time()
num = range(10000000)
sq_num = [num ** 2 for num in num]
end_time = time.time()
end_time - st_time
# Out:
# 1.817387342453003

# %%
price = [100, 120, 80, 50]
ear_per_share = [10, 15, 40, 2]

[(p / e)  if e != 0  else -1 for p, e in zip(price, ear_per_share)]
# Out:
# [10.0, 8.0, 2.0, 25.0]

# %%
date = ['apple', 'banana', 'cherry', 'mango']
[len(words) for words in date ]
# Out:
# [5, 6, 6, 5]

# %%
price = [120, 99, 80, 105, 195]
[p * 0.90 if p > 100 else p for p in price]
# Out:
# [108.0, 99, 80, 94.5, 175.5]

# %%
name = ['karan', 'Kartik', "Shubham"]
sal = [23, 45, 67]

{name[i] : sal[i] for i in  range(len(name))}
# Out:
# {'karan': 23, 'Kartik': 45, 'Shubham': 67}
