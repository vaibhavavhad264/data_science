# %%
from numpy.conftest import dtype

myset = [1, 2, 3, 4]

# %%
myset = set(myset)
print(myset)
# Out:
# {1, 2, 3, 4}

# %%
type(myset)
# Out:
# set

# %%
myset = set([1, 2, 3, 4, 5, 4,3, 2, 1])

# %%
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
myset.add("kkaran")

# %%
myset
# Out:
# {1, 2, 3, 4, 5, 'kkaran'}

# %%
myset.remove('kkaran')

# %%
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
myset = frozenset(["Dal", "Rice", "Chapati"])
myset
# Out:
# frozenset({'Chapati', 'Dal', 'Rice'})

# %%
myset.add("Pulaav")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 myset.add("Pulaav")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
myset
# Out:
# frozenset({'Chapati', 'Dal', 'Rice'})

# %%
myset = set(["Dal", "Rice", "Chapati"])

# %%
"Dal" in myset
# Out:
# True

# %%
transaction = [
    {'customer_name' : 'Vaibhav', 'amount' : 56, 'date' : '2024-08-01'},
    {'customer_name' : 'Vaibhav', 'amount' : 45.6, 'date' : '2024-09-05'},
    {'customer_name' : 'Raam', 'amount' : 61.5, 'date' : '2024-09-03'},
    {'customer_name' : 'Karan', 'amount' : 69.69, 'date' : '2024-09-10'},
    {'customer_name' : 'Raam', 'amount' : 13, 'date' : '2024-09-10'},
]

# %%
type(transaction)
# Out:
# list

# %%
customer = set()
for trans in transaction:
    customer.add(trans['customer_name'])
customer
# Out:
# {'Karan', 'Raam', 'Vaibhav'}

# %%
a = {'Ram', 'Ketaki', 'Shyam', 'Karna'}
b = {'Raj', "Lakshuman", 'Lakshmi', 'Hari', 'Shyam'}

# %%
a & b
# Out:
# {'Shyam'}

# %%
a | b
# Out:
# {'Hari', 'Karna', 'Ketaki', 'Lakshmi', 'Lakshuman', 'Raj', 'Ram', 'Shyam'}

# %%
a.intersection(b)
# Out:
# {'Shyam'}

# %%
a.union(b)
# Out:
# {'Hari', 'Karna', 'Ketaki', 'Lakshmi', 'Lakshuman', 'Raj', 'Ram', 'Shyam'}

# %%
a - b
# Out:
# {'Karna', 'Ketaki', 'Ram'}

# %%
a.difference(b)
# Out:
# {'Karna', 'Ketaki', 'Ram'}

# %%
b - a
# Out:
# {'Hari', 'Lakshmi', 'Lakshuman', 'Raj'}

# %%
b.difference(a)
# Out:
# {'Hari', 'Lakshmi', 'Lakshuman', 'Raj'}
