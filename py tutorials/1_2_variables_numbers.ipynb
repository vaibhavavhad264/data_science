# %%
can = "soda"

# %%
can
# Out:
# 'soda'

# %%
can = "beans"

# %%
can
# Out:
# 'beans'

# %%
type(can)
# Out:
# str

# %%
pizza = 100

# %%
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa=10.5

# %%
pizza + samosa
# Out:
# 110.5

# %%
type(pizza+samosa)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
id(pizza)
# Out:
# 1958497946960

# %%
p = pizza

# %%
id(p)
# Out:
# 1958497946960

# %%
p
# Out:
# 100

# %%
pizza
# Out:
# 100

# %%
p==pizza
# Out:
# True

# %%
नाव = "Vaibhav"

# %%
नाव
# Out:
# 'Vaibhav'

# %%
l =10
b = 12

# %%
l*b
# Out:
# 120

# %%
type((l*b)/2)
# Out:
# float

# %%
b/l
# Out:
# 1.2

# %%
b//l
# Out:
# 1

# %%
l, b
# Out:
# (10, 12)

# %%
l ** b
# Out:
# 1000000000000

# %%
l = 2.3e5

# %%
type(l)
# Out:
# float

# %%
b = 2.3e-3

# %%
b
# Out:
# 0.0023

# %%
round(34.567, 2)
# Out:
# 34.57

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.isqrt(25)
# Out:
# 5

# %%
math.hcf(10, 15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 math.hcf(10, 15)
#
# AttributeError: module 'math' has no attribute 'hcf'

# %%
format(5, 'b')
# Out:
# '101'
