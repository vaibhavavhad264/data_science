# %%
json_string = '''
    {
        "name": "Vaibhav",
        "age": 30,
        "is_employed": true,
        "skill" : ["Python", "Data Analysis", "ML"],
        "Address" : {
            "Street" : "123 Main Street",
            "city" : "San Francisco",
            "state" : "CA"
        }
    }

'''

# %%
type(json_string)
# Out:
# str

# %%
import json

record = json.loads(json_string)
record
# Out:
# {'name': 'Vaibhav',
#  'age': 30,
#  'is_employed': True,
#  'skill': ['Python', 'Data Analysis', 'ML'],
#  'Address': {'Street': '123 Main Street',
#   'city': 'San Francisco',
#   'state': 'CA'}}

# %%
type(record)
# Out:
# dict

# %%
record["name"]
# Out:
# 'Vaibhav'

# %%
data = {
        "name": "Vaibhav",
        "age": 30,
        "is_employed": True,
        "skill" : ["Python", "Data Analysis", "ML"],
        "Address" : {
            "Street" : "123 Main Street",
            "city" : "San Francisco",
            "state" : "CA"
        }
    }

# %%
type(data)
# Out:
# dict

# %%
data_str = json.dumps(data)
type(data_str)
# Out:
# str

# %%
data_str
# Out:
# '{"name": "Vaibhav", "age": 30, "is_employed": true, "skill": ["Python", "Data Analysis", "ML"], "Address": {"Street": "123 Main Street", "city": "San Francisco", "state": "CA"}}'

# %%
data['name']
# Out:
# 'Vaibhav'

# %%
with open("output.json", 'w') as f:
    json.dump(data, f, indent = 4)

# %%
with open("output.json", "r") as file:
    pr = json.load(file)
pr
# Out:
# {'name': 'Vaibhav',
#  'age': 30,
#  'is_employed': True,
#  'skill': ['Python', 'Data Analysis', 'ML'],
#  'Address': {'Street': '123 Main Street',
#   'city': 'San Francisco',
#   'state': 'CA'}}

# %%
with open("products.json", "r") as f:
    product = json.load(f)
product
# Out:
# [{'product_id': 1,
#   'sku': 'ABC123',
#   'name': 'Wireless Mouse',
#   'price': 25.99,
#   'description': 'A comfortable wireless mouse with ergonomic design.',
#   'in_stock': True,
#   'category': 'Electronics'},
#  {'product_id': 2,
#   'sku': 'XYZ789',
#   'name': 'Mechanical Keyboard',
#   'price': 89.99,
#   'description': 'A high-quality mechanical keyboard with customizable keys.',
#   'in_stock': True,
#   'category': 'Electronics'},
#  {'product_id': 3,
#   'sku': 'LMN456',
#   'name': 'USB-C Charger',
#   'price': 19.99,
#   'description': 'A fast-charging USB-C charger with multiple ports.',
#   'in_stock': False,
#   'category': 'Accessories'},
#  {'product_id': 4,
#   'sku': 'QWE234',
#   'name': 'Bluetooth Speaker',
#   'price': 49.99,
#   'description': 'A portable Bluetooth speaker with excellent sound quality.',
#   'in_stock': True,
#   'category': 'Audio'},
#  {'product_id': 5,
#   'sku': 'RTY678',
#   'name': 'Smartphone Stand',
#   'price': 14.99,
#   'description': 'An adjustable smartphone stand for hands-free viewing.',
#   'in_stock': True,
#   'category': 'Accessories'}]

# %%
type(product)
# Out:
# list

# %%
product[1]["price"]
# Out:
# 89.99

# %%
j_string = '''
    {
        "name": "Vaibhav",
        "age": 30,
        "is_employed": true,
        "skill" : ["Python", "Data Analysis", "ML"],
        "Address" : {
            "Street" : "123 Main Street",
            "city" : "San Francisco",
            "state" : "CA"
        }
    }
'''

# %%
type(j_string)
# Out:
# str

# %%
import json as j

rec = j.loads(j_string)
rec
# Out:
# {'name': 'Vaibhav',
#  'age': 30,
#  'is_employed': True,
#  'skill': ['Python', 'Data Analysis', 'ML'],
#  'Address': {'Street': '123 Main Street',
#   'city': 'San Francisco',
#   'state': 'CA'}}

# %%
type(rec)
# Out:
# dict

# %%
rec["skill"]
# Out:
# ['Python', 'Data Analysis', 'ML']

# %%
dataa = {
        "name": "Vaibhav",
        "age": 30,
        "is_employed": True,
        "skill" : ["Python", "Data Analysis", "ML"],
        "Address" : {
            "Street" : "123 Main Street",
            "city" : "San Francisco",
            "state" : "CA"
        }
    }

# %%
type(dataa)
# Out:
# dict

# %%
dataa = j.dumps(dataa)

# %%
type(dataa)
# Out:
# str

# %%
with open("output.json", 'w') as f1:
    j.dump(dataa, f1, indent = 4)

# %%
with open("output.json", "r") as file:
    pr = j.load(file)
pr
# Out:
# {'name': 'Vaibhav',
#  'age': 30,
#  'is_employed': True,
#  'skill': ['Python', 'Data Analysis', 'ML'],
#  'Address': {'Street': '123 Main Street',
#   'city': 'San Francisco',
#   'state': 'CA'}}
