# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017           32          6      Rain
# 1  1/2/2017       -99999          7     Sunny
# 2  1/3/2017           28     -99999      Snow
# 3  1/4/2017       -99999          7  no event
# 4  1/5/2017           32     -99999      Rain
# 5  1/6/2017           31          2     Sunny
# 6  1/6/2017           34     -88888  no event

# %%
df.replace([-99999, -88888], 0, inplace = True)
print(df)
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017           32          6      Rain
# 1  1/2/2017            0          7     Sunny
# 2  1/3/2017           28          0      Snow
# 3  1/4/2017            0          7  no event
# 4  1/5/2017           32          0      Rain
# 5  1/6/2017           31          2     Sunny
# 6  1/6/2017           34          0  no event

# %%
df.replace({
    "event" : "No Event"
})
print(df)
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017           32          6      Rain
# 1  1/2/2017            0          7     Sunny
# 2  1/3/2017           28          0      Snow
# 3  1/4/2017            0          7  no event
# 4  1/5/2017           32          0      Rain
# 5  1/6/2017           31          2     Sunny
# 6  1/6/2017           34          0  no event

# %%
import numpy as np

df.replace({
    "temperature" : -99999,
    "windspeed" : [-99999, -88888],
    "event" : "No Event"
}, np.nan, inplace = True)

# %%
print(df)
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          NaN        7.0     Sunny
# 2  1/3/2017         28.0        NaN      Snow
# 3  1/4/2017          NaN        7.0  no event
# 4  1/5/2017         32.0        NaN      Rain
# 5  1/6/2017         31.0        2.0     Sunny
# 6  1/6/2017         34.0        NaN  no event

# %%
df = pd.DataFrame({
    "score" : ["exceptional", "good", "average", "poor", "good"],
    "student" : ["Ram", "Arjun", "Karan", "Sita", "Gita"]
})
print(df)
# Out:
#          score student
# 0  exceptional     Ram
# 1         good   Arjun
# 2      average   Karan
# 3         poor    Sita
# 4         good    Gita

# %%
df.replace(["exceptional", "good", "average", "poor"], [4, 3, 2, 1], inplace = True)
# Out:
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_2236\3556543118.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(["exceptional", "good", "average", "poor"], [4, 3, 2, 1], inplace = True)

# %%
print(df)
# Out:
#    score student
# 0      4     Ram
# 1      3   Arjun
# 2      2   Karan
# 3      1    Sita
# 4      3    Gita
