# %%
import numpy as np

arr = np.array([1, 2, 3])
arr
# Out:
# array([1, 2, 3])

# %%
lst = list(range(100))
lst[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
import sys

sys.getsizeof(lst[0]) * len(lst)
# Out:
# 2400

# %%
np_array = np.arange(100)
np_array[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
np_array.nbytes
# Out:
# 8

# %%
import time

SIZE = 1000000
lst1 = list(range(SIZE))
lst2 = list(range(SIZE))

st_time = time.time()
add = [x+y for x, y in zip(lst1, lst2)]
end_time = time.time()

print("Python list took : ", end_time - st_time)
# Out:
# Python list took :  0.06253886222839355

# %%
arr1 = np.arange(SIZE)
arr2 = np.arange(SIZE)

st_time = time.time()
arr3 = arr1 + arr2
end_time = time.time()

print("Python numpy array took : ", end_time - st_time)
# Out:
# Python numpy array took :  0.0021784305572509766
